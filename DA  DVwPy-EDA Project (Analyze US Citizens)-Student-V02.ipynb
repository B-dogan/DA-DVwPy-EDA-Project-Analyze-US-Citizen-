# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df = pd.read_csv("adult_eda.csv")
df.sample(8)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 27276   47           Private  170850     Bachelors         13.000
# 6428    19           Private  121972       HS-grad          9.000
# 24830   49         Local-gov   31267     Bachelors         13.000
# 15273   30           Private  340917     Bachelors         13.000
# 18986   33  Self-emp-not-inc  112952  Some-college         10.000
# 1931    50                 ?  156008          11th          7.000
# 29971   64      Self-emp-inc  161325    Assoc-acdm         12.000
# 32076   59       Federal-gov  293971  Some-college         10.000
#
#            marital-status      occupation relationship   race     sex  \
# 27276  Married-civ-spouse    Tech-support      Husband  White    Male
# 6428        Never-married   Other-service          NaN  Black    Male
# 24830  Married-civ-spouse  Prof-specialty      Husband  White    Male
# 15273  Married-civ-spouse    Craft-repair      Husband  White    Male
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.loc[df.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 4881    25           Private  308144     Bachelors         13.000
# 5104    90           Private   52386  Some-college         10.000
# 9171    21           Private  250051  Some-college         10.000
# 11631   20           Private  107658  Some-college         10.000
# 13084   25           Private  195994       1st-4th          2.000
# 15059   21           Private  243368     Preschool          1.000
# 17040   46           Private  173243       HS-grad          9.000
# 18555   30           Private  144593       HS-grad          9.000
# 18698   19           Private   97261       HS-grad          9.000
# 21318   19           Private  138153  Some-college         10.000
# 21490   19           Private  146679  Some-college         10.000
# 21875   49           Private   31267       7th-8th          4.000
# 22300   25           Private  195994       1st-4th          2.000
# ...

# %%
len(df.loc[df.duplicated()])   # There are 24 duplicate values
                               # when i drop these i should have 32537 rows
# Out:
# 24

# %%
df.loc[~df.duplicated()]
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df = df.loc[~df.duplicated()]
df.shape
# Out:
# (32537, 15)

# %%
df.describe()
# Out:
#             age      fnlwgt  education-num  capital-gain  capital-loss  \
# count 32537.000   32537.000      31735.000     32537.000     32537.000
# mean     38.586  189780.849         10.084      1078.444        87.368
# std      13.638  105556.471          2.575      7387.957       403.102
# min      17.000   12285.000          1.000         0.000         0.000
# 25%      28.000  117827.000          9.000         0.000         0.000
# 50%      37.000  178356.000         10.000         0.000         0.000
# 75%      48.000  236993.000         12.000         0.000         0.000
# max      90.000 1484705.000         16.000     99999.000      4356.000
#
#        hours-per-week
# count       32537.000
# mean           40.440
# std            12.347
# min             1.000
# 25%            40.000
# 50%            40.000
# 75%            45.000
# max            99.000

# %%
df.describe(include="O")
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32537     32537               32537           32537        27473
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22673     10494               14970            4136        13187
#
#          race    sex native-country salary
# count   32537  32537          32537  32537
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27795  21775          29153  24698

# %%
df.rename(columns={"education-num":"education_num",
                   "marital-status":"marital_status",
                   "capital-gain":"capital_gain",
                   "capital-loss":"capital_loss",
                   "hours-per-week":"hours_per_week",
                   "native-country":"native_country",
                   "sex":"gender"
                   },inplace=True)

# %%
df.head(2)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
#
#        marital_status       occupation   relationship   race gender  \
# 0       Never-married     Adm-clerical  Not-in-family  White   Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White   Male
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K

# %%
df.isna().sum()  
##It looks like there is missing data in columns education-num and relationship,but we'll also take a look at the strange values
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# gender               0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %% [markdown]
# relationship  ve  education_num 'daki missing valuları -----> marital_status ve education  featurelarıyla doldurabilir miyiz ?

# %%
df.shape
# Out:
# (32537, 15)

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# gender            0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
object_col = df.select_dtypes(include="O")  # O:object
object_col
# Out:
#               workclass   education      marital_status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race  gender native_country salary
# ...

# %%
object_col.columns
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'gender', 'native_country', 'salary'],
#       dtype='object')

# %%
for col in object_col.columns:
    print(col)
    print("--"*10)
    print(df[col].value_counts(dropna=False))
    print("##"*20)
# Out:
# workclass
# --------------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ########################################
# education
# --------------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ########################################
# marital_status
# --------------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %% [markdown]
# ### strange values :

# %% [raw]
# workclass ------> 1836 tane "?" var
# education ------> yok
# marital_status ------> yok
# occupation ------> 1843 tane "?" var
# relationship  ------> yok
# race ----------> yok
# sex ----------> yok
# native_country -----------> 582 tane "?" var
# salary --------> yok

# %%
## teyit edelim : 
df.isin(["?"]).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# gender               0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     582
# salary               0
# dtype: int64

# %% [markdown]
# ## missing values :

# %% [raw]
# relationship  ------> NaN  değer sayısı: 5064
# education_num   ------>    802 NaN değer var.

# %%
df.describe(include="O").T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# gender          32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
df.describe()
# Out:
#             age      fnlwgt  education_num  capital_gain  capital_loss  \
# count 32537.000   32537.000      31735.000     32537.000     32537.000
# mean     38.586  189780.849         10.084      1078.444        87.368
# std      13.638  105556.471          2.575      7387.957       403.102
# min      17.000   12285.000          1.000         0.000         0.000
# 25%      28.000  117827.000          9.000         0.000         0.000
# 50%      37.000  178356.000         10.000         0.000         0.000
# 75%      48.000  236993.000         12.000         0.000         0.000
# max      90.000 1484705.000         16.000     99999.000      4356.000
#
#        hours_per_week
# count       32537.000
# mean           40.440
# std            12.347
# min             1.000
# 25%            40.000
# 50%            40.000
# 75%            45.000
# max            99.000

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education_num   31735 non-null  float64
#  5   marital_status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    27473 non-null  object
#  8   race            32537 non-null  object
#  9   gender          32537 non-null  object
#  10  capital_gain    32537 non-null  int64
#  11  capital_loss    32537 non-null  int64
#  12  hours_per_week  32537 non-null  int64
#  13  native_country  32537 non-null  object
#  14  salary          32537 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 4.0+ MB

# %%
df.head(2)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
#
#        marital_status       occupation   relationship   race gender  \
# 0       Never-married     Adm-clerical  Not-in-family  White   Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White   Male
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K

# %% [markdown]
# ## Salary (Target Feature)

# %%
# salary levels ---->            >50K  |   <= 50K

# %%
df["salary"].value_counts(dropna=False)
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
salary_index = df["salary"].value_counts(dropna=False).index
salary_index                                                         # countplotta gerek yok bunlara kendisi sayıyor zaten
# Out:
# Index(['<=50K', '>50K'], dtype='object')

# %%
salary_unique = df["salary"].value_counts(dropna=False).values
salary_unique
# Out:
# array([24698,  7839], dtype=int64)

# %%
fig,ax = plt.subplots()
ax = sns.countplot(x = "salary" ,data=df)

# %%
# değerleri üzerine de yazdırmak istiyorsak : 
fig,ax = plt.subplots()
ax = sns.countplot(x = "salary" ,data=df)
for container in ax.containers:
    plt.bar_label(container,fontsize = 12)

# %%
df["salary"].value_counts(normalize=True)
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
plt.pie(salary_unique,labels=salary_index,labeldistance=1.2,autopct="%.1f",shadow=True,explode=[0.,0.3])
plt.title("Percentage of Income-Levels",fontsize = 16)  ;

# %% [raw]
# ### salary:
# 7839 kişi 50K'den fazla maaş alıyormuş    --------> yani %24.1
# 50K ve aşağısında ise 24698 kişi var maaş alan.  --------> yani % 75.9
# rastgele birini seçsem 50K'dan az maaşının olma ihtimali çok yüksek
# Yılda 50 bin dolardan fazla kazananların sayısı, bundan daha az kazananların üçte biri.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## 1-) age

# %%
sns.boxplot(x = "age",data=df)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
ax = sns.displot(data=df,x = "age",bins = 20,kde = True)

# %% [markdown]
# 25-48 yaş arasında bir yoğunluk var.

# %%
df["age"].describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %%
sns.boxplot(x = "salary",y = "age",data=df,hue="salary")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='age'>

# %%
sns.histplot(x ="age",data=df,hue="salary",kde=True,bins=15);

# %% [raw]
# En yüksek gelire sahip kişilerin çoğunlukla 39-45 yaş aralığında olduğunu görebiliriz.
# df'mimizdeki insanların çoğu 20-35 yaş civarında.

# %%
sns.kdeplot(x ="age",data=df,hue="salary",shade=True);

# %%
def age_group(x):
    x = int(x)
    x = abs(x)
    if( 18 < x < 31 ):
        return "19-30"
    if( 30 < x < 41 ):
        return "31-40"
    if( 40 < x < 51 ):
        return "41-50"
    if( 50 < x < 61 ):
        return "51-60"
    if( 60 < x < 71 ):
        return "61-70"
    else:
        return "Greater than 70"

df['age_group'] = df['age'].apply(age_group)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary age_group
# 0          2174             0              40  United-States  <=50K     31-40
# ...

# %%
plt.figure(figsize=(12,6))
order_list = ['19-30', '31-40', '41-50', '51-60', '61-70', 'Greater than 70']
sns.countplot(df['age_group'], hue = df['salary'], palette='viridis', order = order_list)
plt.title('Income of Individuals of Different Age Groups', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# ### 50K dolardan fazla kazananların belli bir dereceye kadar yaş arttıkça arttığını görüyoruz.

# %%
df.groupby("salary")["age"].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [raw]
# maaşı 50K'dan fazla olanlar için :
# min yaş -------> 19
# max yaş -------> 90
# mean yaş -------> 44.25
# # yaş arttıkça 50K'dan fazla kazanma ihtimali artıyor gibi buna scatter ile bakalım bi AMA 51-60 ARASINDA 50K'dan az kazanılıyor genelde insanlar bunu da unutmayalım.

# %% [raw]
# maaşı 50K ve daha az olanlar için :
# min yaş -------> 17
# max yaş -------> 90
# mean yaş -------> 36.787

# %% [raw]
# ## bizim exterme değerler outlier OLMAYABİLİR çünkü median ve mean arasında fark fazla yok
# bunun tespiti için usa'deki emeklilik durumuna bi bakalım 90 yaşında büyük olanların veya 70 yaşından büyük olanların mesleğine vs bakmak gerekiyor

# %% [markdown]
# # 2-) fnlwgt

# %% [raw]
# # bu değişken örnekleme ağırlığını bize veriyor yani ilgili gözlemin kaç kişiyi temsil ettiğine dair ağırlık değeri ve target feature ile bir bağlantısı olmadığından ileride kaldıracağımız için bunu incelemeye gerek duymadım.

# %% [markdown]
# # 3-) capital_gain

# %%
sns.boxplot(x = "capital_gain",data=df);

# %% [raw]
# ## 0'lar çoğunlukta olduğu için bu şekilde.
# Minimum ve ortalama sermaye kazancı 0 iken, maksimum 99999'dur. Bu garip görünüyor, belki veri toplamada bir hata olabilir.

# %%
sns.histplot(x ="capital_gain",data=df,kde=True,bins=15);

# %%
df["capital_gain"].describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %%
sns.histplot(x ="capital_gain",data=df,hue="salary",kde=True,bins=15);

# %%
sns.kdeplot(x ="capital_gain",data=df,hue="salary",shade=True);

# %%
sns.boxplot(x = "salary",y = "capital_gain",data=df,hue="salary");

# %% [markdown]
# *** capital_gain 100.000 olanın maaşı 50K'dan fazlaymış.

# %%
df.groupby("salary")["capital_gain"].describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [raw]
# sıfıra eşit olmayan capital_gain için describe:

# %%
df.loc[df["capital_gain"] != 0]  # sonuçta bu da bana bir df döndürüyor!
# Out:
#        age         workclass  fnlwgt    education  education_num  \
# 0       39         State-gov   77516    Bachelors         13.000
# 8       31           Private   45781      Masters         14.000
# 9       42           Private  159449    Bachelors         13.000
# 59      30           Private  188146      HS-grad          9.000
# 60      30           Private   59496    Bachelors         13.000
# ...    ...               ...     ...          ...            ...
# 32515   66       Federal-gov   47358         10th          6.000
# 32518   57         Local-gov  110417      HS-grad          9.000
# 32538   38           Private  139180    Bachelors         13.000
# 32548   65  Self-emp-not-inc   99359  Prof-school         15.000
# 32560   52      Self-emp-inc  287927      HS-grad          9.000
#
#            marital_status         occupation   relationship   race  gender  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.loc[df["capital_gain"] != 0].groupby("salary")["capital_gain"].describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [raw]
# Result : .....................................................................

# %% [markdown]
# # 4-) capital_loss

# %%
sns.boxplot(x = "capital_loss",data=df)
# Out:
# <AxesSubplot:xlabel='capital_loss'>

# %%
sns.histplot(x = "capital_loss",data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='capital_loss', ylabel='Count'>

# %%
df["capital_loss"].describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %%
sns.boxplot(x="salary",hue="salary",data=df,y="capital_loss")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='capital_loss'>

# %%
sns.kdeplot(x ="capital_loss",data=df,hue="salary",shade=True);

# %%
df.groupby("salary")["capital_loss"].describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %%
df.loc[df["capital_loss"] != 0].groupby("salary")["capital_loss"].describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [raw]
# Result : .....................................................

# %% [markdown]
# # 5-) hours_per_week

# %%
sns.boxplot(x="hours_per_week",data=df)
# Out:
# <AxesSubplot:xlabel='hours_per_week'>

# %%
df["hours_per_week"].describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %%
sns.kdeplot(x="hours_per_week",data=df,shade=True)
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Density'>

# %%
sns.histplot(x="hours_per_week",data=df,bins=8)
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Count'>

# %%
sns.boxplot(x="salary",y="hours_per_week",data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='hours_per_week'>

# %%
sns.kdeplot(x="hours_per_week",data=df,shade=True,hue="salary")
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Density'>

# %%
df.groupby("salary")["hours_per_week"].describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [raw]
# result :
# ## median = 40.00
# ### 99 vs outlier gibi duruyor ama bi insan günde 15 saat çalışabilir eğer kendi işiyse bunu göz önünde bulunduralım.
# ### min olarak haftalık 1 saat çalışan gözüküyor bunun maaşına vs bakalım bu outlier olabilir ya da yanlış girilmiş de olabilir buna ve bunun gibi durumlara dikkat edelim.

# %%
sns.pairplot(data=df,corner=True,hue="salary",palette="viridis")

# %%
num_features = df.select_dtypes(include=['int'])
num_features
# Out:
#        age  fnlwgt  capital_gain  capital_loss  hours_per_week
# 0       39   77516          2174             0              40
# 1       50   83311             0             0              13
# 2       38  215646             0             0              40
# 3       53  234721             0             0              40
# 4       28  338409             0             0              40
# ...    ...     ...           ...           ...             ...
# 32556   27  257302             0             0              38
# 32557   40  154374             0             0              40
# 32558   58  151910             0             0              40
# 32559   22  201490             0             0              20
# 32560   52  287927         15024             0              40
#
# [32537 rows x 5 columns]

# %%
num_features.hist(figsize=(12,10))
plt.tight_layout;

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %%
df["education_num"].describe()
# Out:
# count   31735.000
# mean       10.084
# std         2.575
# min         1.000
# 25%         9.000
# 50%        10.000
# 75%        12.000
# max        16.000
# Name: education_num, dtype: float64

# %%
# ortalama eğitim yılı 10 yıldır

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education_num   31735 non-null  float64
#  5   marital_status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    27473 non-null  object
#  8   race            32537 non-null  object
#  9   gender          32537 non-null  object
#  10  capital_gain    32537 non-null  int64
#  11  capital_loss    32537 non-null  int64
#  12  hours_per_week  32537 non-null  int64
#  13  native_country  32537 non-null  object
#  14  salary          32537 non-null  object
#  15  age_group       32537 non-null  object
# dtypes: float64(1), int64(5), object(10)
# ...

# %%
df["education"].value_counts(dropna=False)
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df["education_num"].value_counts(dropna=False)
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df.groupby(["education"],dropna=False)["education_num"].value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# ...

# %%
sns.countplot(x="education",data=df)
plt.xticks(rotation=270);

# %%
sns.countplot(x="education_num",data=df)
# Out:
# <AxesSubplot:xlabel='education_num', ylabel='count'>

# %%
df.groupby(["education","salary"])["salary"].count()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     <=50K      107
#               >50K       306
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       <=50K      763
#               >50K       959
# Preschool     <=50K       50
# Prof-school   <=50K      153
#               >50K       423
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
sns.countplot(x ="education",data=df,hue="salary")
plt.xticks(rotation=90);

# %%
df.groupby(["education_num","salary"])["salary"].count()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         <=50K      751
#                >50K       935
# 15.000         <=50K      149
#                >50K       410
# 16.000         <=50K      103
# ...

# %%
sns.countplot(x ="education_num",data=df,hue="salary");

# %%
sns.boxplot(x="salary",y = "education_num",hue="salary",data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='education_num'>

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
df["education"].apply(mapping_education).value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
df["education_summary"] = df.applymap(mapping_education)["education"]

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary age_group  \
# 0          2174             0              40  United-States  <=50K     31-40
# ...

# %%
sns.countplot(x = "education_summary" ,data=df);

# %%
df.groupby(["education_summary","salary"])["salary"].count()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
sns.countplot(x = "education_summary",data=df,hue="salary");

# %%
df_perc = pd.DataFrame(df.groupby("education_summary")["salary"].value_counts(normalize = True))
df_perc.columns = ["percentage"]
df_perc = df_perc.unstack(level=0)
df_perc
# Out:
#                         percentage
# education_summary high_level_grade low_level_grade medium_level_grade
# salary
# <=50K                        0.515           0.943              0.818
# >50K                         0.485           0.057              0.182

# %%
fig, ax=plt.subplots(1,3, figsize=(16,5))

colors = ["#ffb3b3", "#99ceff"]

ax[0].pie(x=df_perc[("percentage","high_level_grade")], labels=df.salary.value_counts().index, colors=colors, autopct="%.2f%%" )
ax[0].set_title("high_level_grade")

ax[1].pie(x=df_perc.percentage.low_level_grade, labels=df.salary.value_counts().index,colors=colors, autopct="%.2f%%");
ax[1].set_title("low_level_grade")

ax[2].pie(x=df_perc.percentage.medium_level_grade, labels=df.salary.value_counts().index, colors=colors, autopct="%.2f%%");
ax[2].set_title("medium_level_grade")
plt.show()

# %%
df.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
sns.countplot(x = "salary",data=df,hue="education_summary");

# %%
df_perc2 = pd.DataFrame(df.groupby("salary")["education_summary"].value_counts(normalize=True))
df_perc2.columns = ["percentage"]
df_perc2 = df_perc2.unstack(level=0).sort_values(("percentage","<=50K"),ascending = False)
df_perc2
# Out:
#                    percentage
# salary                  <=50K  >50K
# education_summary
# medium_level_grade      0.670 0.470
# high_level_grade        0.168 0.499
# low_level_grade         0.162 0.031

# %%
fig,ax = plt.subplots(1,2,figsize=(14,7))
ax[0].pie(x = df_perc2["percentage"]["<=50K"],labels=df_perc2.index,autopct="%.2f")
ax[0].set_title("<=50K")

ax[1].pie(x = df_perc2["percentage"][">50K"],labels=df_perc2.index,autopct="%.2f")
ax[1].set_title(">50K")
# Out:
# Text(0.5, 1.0, '>50K')

# %% [markdown]
# ## marital_status & relationship

# %%
df["marital_status"].value_counts(dropna=False)
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df["relationship"].value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.groupby(["relationship","marital_status"])["marital_status"].count()
# Out:
# relationship    marital_status
# Husband         Married-AF-spouse            9
#                 Married-civ-spouse       13178
# Not-in-family   Divorced                  2403
#                 Married-civ-spouse          17
#                 Married-spouse-absent      211
#                 Never-married             4694
#                 Separated                  420
#                 Widowed                    547
# Other-relative  Divorced                   110
#                 Married-AF-spouse            1
#                 Married-civ-spouse         124
#                 Married-spouse-absent       32
#                 Never-married              611
#                 Separated                   55
#                 Widowed                     48
# Unmarried       Divorced                  1600
#                 Married-spouse-absent      130
#                 Never-married              881
#                 Separated                  451
# ...

# %%
sns.countplot(x = "marital_status",data=df);

# %%
df.groupby("marital_status")["salary"].value_counts(dropna=False)
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
sns.countplot(x = "marital_status",data=df,hue="salary");

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
df["marital_status"].apply(mapping_marital_status).value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
df["marital_status_summary"] = df["marital_status"].transform(mapping_marital_status)
df["marital_status_summary"]
# Out:
# 0        unmarried
# 1          married
# 2        unmarried
# 3          married
# 4          married
#            ...
# 32556      married
# 32557      married
# 32558    unmarried
# 32559    unmarried
# 32560      married
# Name: marital_status_summary, Length: 32537, dtype: object

# %%
df.head(2)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
#
#        marital_status       occupation   relationship   race gender  \
# 0       Never-married     Adm-clerical  Not-in-family  White   Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White   Male
#
#    capital_gain  capital_loss  hours_per_week native_country salary age_group  \
# 0          2174             0              40  United-States  <=50K     31-40
# 1             0             0              13  United-States  <=50K     41-50
#
#   education_summary marital_status_summary
# 0  high_level_grade              unmarried
# 1  high_level_grade                married

# %%
sns.countplot(x = "marital_status_summary",data=df)
# Out:
# <AxesSubplot:xlabel='marital_status_summary', ylabel='count'>

# %%
df.groupby("marital_status_summary")["salary"].value_counts(dropna=False)
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
sns.countplot(x = "marital_status_summary",data=df,hue="salary")
# Out:
# <AxesSubplot:xlabel='marital_status_summary', ylabel='count'>

# %%
df.groupby("salary")["marital_status_summary"].value_counts(dropna=False)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
sns.countplot(x ="salary" ,data=df,hue="marital_status_summary")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# ## worclass

# %%
df["workclass"].value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
sns.countplot(x="workclass",data=df);

# %%
df.groupby("workclass")["salary"].value_counts()
# Out:
# workclass         salary
# ?                 <=50K      1645
#                   >50K        191
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
sns.countplot(x ="workclass" ,hue="salary",data=df);

# %%
df.groupby("workclass")["salary"].value_counts(normalize = True)
# Out:
# workclass         salary
# ?                 <=50K    0.896
#                   >50K     0.104
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
percentage_workclass = pd.DataFrame(df.groupby("workclass")["salary"].value_counts(normalize = True))
percentage_workclass.columns
# Out:
# Index(['salary'], dtype='object')

# %%
percentage_workclass.columns = ["percentage"]
percentage_workclass = percentage_workclass.reset_index()
percentage_workclass
# Out:
#            workclass salary  percentage
# 0                  ?  <=50K       0.896
# 1                  ?   >50K       0.104
# 2        Federal-gov  <=50K       0.614
# 3        Federal-gov   >50K       0.386
# 4          Local-gov  <=50K       0.705
# 5          Local-gov   >50K       0.295
# 6       Never-worked  <=50K       1.000
# 7            Private  <=50K       0.781
# 8            Private   >50K       0.219
# 9       Self-emp-inc   >50K       0.557
# 10      Self-emp-inc  <=50K       0.443
# 11  Self-emp-not-inc  <=50K       0.715
# 12  Self-emp-not-inc   >50K       0.285
# 13         State-gov  <=50K       0.728
# 14         State-gov   >50K       0.272
# 15       Without-pay  <=50K       1.000

# %%
ax = sns.barplot(x = "workclass",y = "percentage",hue="salary",data=percentage_workclass)
plt.xticks(rotation = 90)
for container in ax.containers:
     plt.bar_label(container,fontsize = 12,fmt='%.2f%%');

# %% [markdown]
# ## occupation

# %%
df["occupation"].value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
sns.countplot(x="occupation",data=df)
plt.xticks(rotation = 90);

# %%
df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# ?                  <=50K     1652
#                    >50K       191
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
# ...

# %%
sns.countplot(x ="occupation" ,hue="salary",data=df)
plt.xticks(rotation = 90);

# %%
df.groupby("occupation")["salary"].value_counts(normalize = True)
# Out:
# occupation         salary
# ?                  <=50K    0.896
#                    >50K     0.104
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
# ...

# %%
percentage_occupation = pd.DataFrame(df.groupby("occupation")["salary"].value_counts(normalize = True))
percentage_occupation.columns
# Out:
# Index(['salary'], dtype='object')

# %%
percentage_occupation.columns = ["percentage"]
percentage_occupation = percentage_occupation.reset_index()
percentage_occupation
# Out:
#            occupation salary  percentage
# 0                   ?  <=50K       0.896
# 1                   ?   >50K       0.104
# 2        Adm-clerical  <=50K       0.865
# 3        Adm-clerical   >50K       0.135
# 4        Armed-Forces  <=50K       0.889
# 5        Armed-Forces   >50K       0.111
# 6        Craft-repair  <=50K       0.773
# 7        Craft-repair   >50K       0.227
# 8     Exec-managerial  <=50K       0.516
# 9     Exec-managerial   >50K       0.484
# 10    Farming-fishing  <=50K       0.884
# 11    Farming-fishing   >50K       0.116
# 12  Handlers-cleaners  <=50K       0.937
# 13  Handlers-cleaners   >50K       0.063
# 14  Machine-op-inspct  <=50K       0.875
# 15  Machine-op-inspct   >50K       0.124
# 16      Other-service  <=50K       0.958
# 17      Other-service   >50K       0.042
# 18    Priv-house-serv  <=50K       0.993
# 19    Priv-house-serv   >50K       0.007
# 20     Prof-specialty  <=50K       0.551
# 21     Prof-specialty   >50K       0.449
# ...

# %%
ax = sns.barplot(x = "occupation",y = "percentage",hue="salary",data=percentage_occupation)
plt.xticks(rotation = 90)
for container in ax.containers:
     plt.bar_label(container,fontsize = 12,fmt='%.1f%%');

# %% [markdown]
# ## race

# %%
df["race"].value_counts(dropna=False)
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
sns.countplot(x="race",data=df)
plt.xticks(rotation = 45);

# %%
df.groupby("race")["salary"].value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
sns.countplot(x ="race" ,hue="salary",data=df);

# %%
df.groupby("race")["salary"].value_counts(normalize = True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
percentage_race = pd.DataFrame(df.groupby("race")["salary"].value_counts(normalize = True))
percentage_race.columns
# Out:
# Index(['salary'], dtype='object')

# %%
percentage_race.columns = ["percentage"]
percentage_race = percentage_race.reset_index()
percentage_race
# Out:
#                  race salary  percentage
# 0  Amer-Indian-Eskimo  <=50K       0.884
# 1  Amer-Indian-Eskimo   >50K       0.116
# 2  Asian-Pac-Islander  <=50K       0.734
# 3  Asian-Pac-Islander   >50K       0.266
# 4               Black  <=50K       0.876
# 5               Black   >50K       0.124
# 6               Other  <=50K       0.908
# 7               Other   >50K       0.092
# 8               White  <=50K       0.744
# 9               White   >50K       0.256

# %%
ax = sns.barplot(x = "race",y = "percentage",hue="salary",data=percentage_race)
plt.xticks(rotation = 90)
for container in ax.containers:
     plt.bar_label(container,fontsize = 12,fmt='%.2f%%');

# %% [markdown]
# ## gender

# %%
df["gender"].value_counts(dropna=False)
# Out:
# Male      21775
# Female    10762
# Name: gender, dtype: int64

# %%
sns.countplot(x="gender",data=df)
plt.xticks(rotation = 90);

# %%
df.groupby("gender")["salary"].value_counts()
# Out:
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
sns.countplot(x ="gender" ,hue="salary",data=df)
plt.xticks(rotation = 90);

# %%
df.groupby("gender")["salary"].value_counts(normalize = True)
# Out:
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
percentage_gender = pd.DataFrame(df.groupby("gender")["salary"].value_counts(normalize = True))
percentage_gender.columns
# Out:
# Index(['salary'], dtype='object')

# %%
percentage_gender.columns = ["percentage"]
percentage_gender = percentage_gender.reset_index()
percentage_gender
# Out:
#    gender salary  percentage
# 0  Female  <=50K       0.890
# 1  Female   >50K       0.110
# 2    Male  <=50K       0.694
# 3    Male   >50K       0.306

# %%
ax = sns.barplot(x = "gender",y = "percentage",hue="salary",data=percentage_gender)
plt.xticks(rotation = 90)
for container in ax.containers:
     plt.bar_label(container,fontsize = 12,fmt='%.2f%%');

# %% [markdown]
# ## native_country

# %%
df["native_country"].value_counts(dropna=False)
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
sns.countplot(x="native_country",data=df)
plt.xticks(rotation = 90);

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
df["native_country"].apply(mapping_native_country).value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
df["native_status_summary"] = df["native_country"].transform(mapping_native_country)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race  gender  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary age_group  \
# 0          2174             0              40  United-States  <=50K     31-40
# ...

# %%
sns.countplot(x = "native_status_summary",data=df)
# Out:
# <AxesSubplot:xlabel='native_status_summary', ylabel='count'>

# %%
df.groupby("native_status_summary")["salary"].value_counts(dropna=False)
# Out:
# native_status_summary  salary
# Others                 <=50K      2714
#                        >50K        670
# US                     <=50K     21984
#                        >50K       7169
# Name: salary, dtype: int64

# %%
df.groupby("salary")["native_status_summary"].value_counts(dropna=False)
# Out:
# salary  native_status_summary
# <=50K   US                       21984
#         Others                    2714
# >50K    US                        7169
#         Others                     670
# Name: native_status_summary, dtype: int64

# %%
sns.countplot(x ="salary" ,data=df,hue="native_status_summary")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            27473 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
df.groupby(["salary","gender"])[["age"]].mean()
# Out:
#                  age
# salary gender
# <=50K  Female 36.217
#        Male   37.149
# >50K   Female 42.126
#        Male   44.627

# %%
ax = df.groupby(["salary","gender"])[["age"]].mean().plot(kind="bar",legend=False,xlabel="salary,gender")
ax.bar_label(ax.containers[0],fmt="%.2f");

# %%
df_age_mean = pd.DataFrame(df.groupby(["salary", "gender"])["age"].mean())
df_age_mean = df_age_mean.reset_index()
df_age_mean
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
ax = sns.barplot(data=df_age_mean, x="salary", y="age", hue="gender")

for i in range(len(df_age_mean.salary.value_counts().index)):
    ax.bar_label(ax.containers[i], fmt="%.2f")
plt.legend(fontsize=15);

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
df.sample(3)
# Out:
#        age workclass  fnlwgt     education  education_num marital_status  \
# 4655    19         ?  124884           9th          5.000  Never-married
# 15076   20   Private  184678       HS-grad          9.000  Never-married
# 811     22         ?  219941  Some-college         10.000  Never-married
#
#       occupation   relationship   race  gender  capital_gain  capital_loss  \
# 4655           ?  Not-in-family  White  Female             0             0
# 15076      Sales  Not-in-family  White  Female             0             0
# 811            ?            NaN  Black    Male             0             0
#
#        hours_per_week native_country salary age_group   education_summary  \
# 4655               25  United-States  <=50K     19-30     low_level_grade
# 15076              32  United-States  <=50K     19-30  medium_level_grade
# 811                40  United-States  <=50K     19-30  medium_level_grade
#
#       marital_status_summary native_status_summary
# ...

# %%
df.loc[(df["salary"] == ">50K") & (df["native_status_summary"] == "US")]["workclass"].value_counts(normalize = True) *100
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# ?                   2.455
# Name: workclass, dtype: float64

# %%
df_prcnt= pd.DataFrame(df[(df.native_country == "United-States")&(df.salary == ">50K")]["workclass"].value_counts(normalize=True) * 100)
df_prcnt= df_prcnt.reset_index()
df_prcnt.columns=["workclass", "percentage"]
df_prcnt
# Out:
#           workclass  percentage
# 0           Private      63.314
# 1  Self-emp-not-inc       9.192
# 2         Local-gov       8.021
# 3      Self-emp-inc       7.784
# 4       Federal-gov       4.687
# 5         State-gov       4.547
# 6                 ?       2.455

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
df.loc[(df["salary"] == ">50K") & (df["native_status_summary"] == "US") & (df["workclass"] == "Private") ]\
["occupation"].value_counts(normalize = True) *100
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
df_occp_perc_high=pd.DataFrame(df[(df.native_country == "United-States")&(df.salary == ">50K")&(df.workclass == "Private")]["occupation"].value_counts(normalize=True) * 100)
df_occp_perc_high = df_occp_perc_high.reset_index()
df_occp_perc_high.columns = ["occupation","percentage"]
df_occp_perc_high
# Out:
#            occupation  percentage
# 0     Exec-managerial      26.438
# 1      Prof-specialty      19.476
# 2        Craft-repair      14.695
# 3               Sales      14.475
# 4        Adm-clerical       6.389
# 5    Transport-moving       5.442
# 6        Tech-support       4.428
# 7   Machine-op-inspct       4.428
# 8       Other-service       1.674
# 9   Handlers-cleaners       1.344
# 10    Farming-fishing       0.595
# 11    Protective-serv       0.595
# 12    Priv-house-serv       0.022

# %%
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax= sns.barplot(data=df_occp_perc_high, x="occupation", y="percentage")
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], fmt="%.2f");

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
df.loc[(df["salary"] == ">50K") & (df["race"] == "Asian-Pac-Islander")]["education"].value_counts(normalize = True) *100
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
df_Asian = pd.DataFrame(df[(df.race == "Asian-Pac-Islander")&(df.salary == ">50K")]["education"].value_counts(normalize=True) * 100)
df_Asian = df_Asian.reset_index()
df_Asian.columns = ["education","percentage"]
df_Asian
# Out:
#        education  percentage
# 0      Bachelors      35.145
# 1        Masters      15.580
# 2        HS-grad      12.319
# 3   Some-college      11.957
# 4    Prof-school       9.783
# 5      Doctorate       6.522
# 6      Assoc-voc       3.261
# 7     Assoc-acdm       2.899
# 8        5th-6th       1.087
# 9            9th       0.362
# 10          11th       0.362
# 11          10th       0.362
# 12          12th       0.362

# %%
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax= sns.barplot(data=df_Asian, x="education", y="percentage")
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], fmt="%.2f");

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
df.loc[(df["salary"] == ">50K") & (df["race"] == "Asian-Pac-Islander")&(df["education"] == "Bachelors")]\
["occupation"].value_counts(normalize = True) *100
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
df_Asian_Bachelors = pd.DataFrame(df[(df.race == "Asian-Pac-Islander")&(df.education == "Bachelors")&(df.salary == ">50K")]["occupation"].value_counts(normalize=True) * 100)
df_Asian_Bachelors = df_Asian_Bachelors.reset_index()
df_Asian_Bachelors.columns = ["occupation","percentage"]
df_Asian_Bachelors
# Out:
#            occupation  percentage
# 0     Exec-managerial      27.835
# 1      Prof-specialty      25.773
# 2        Adm-clerical      12.371
# 3               Sales       9.278
# 4       Other-service       9.278
# 5        Craft-repair       7.216
# 6        Tech-support       3.093
# 7     Protective-serv       2.062
# 8    Transport-moving       1.031
# 9   Machine-op-inspct       1.031
# 10    Farming-fishing       1.031

# %%
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax= sns.barplot(data=df_Asian_Bachelors, x="occupation", y="percentage")
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], fmt="%.2f");

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
g = sns.catplot(kind="bar", data=df,
                x="education_summary",
                y="hours_per_week",
                row = "native_status_summary",
                col="marital_status_summary",
                hue="gender",
               height=6,
               aspect=2,
               palette="viridis",
              ci=None)


# iterate through axes
for ax in g.axes.ravel():
    
    # add annotations
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    ax.margins(y=0.2)

;
# Out:
# ''

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            27473 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %%
df.drop(labels=["education","native_country","education_num","relationship","marital_status"], axis = 1, inplace = True)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   occupation              32537 non-null  object
#  4   race                    32537 non-null  object
#  5   gender                  32537 non-null  object
#  6   capital_gain            32537 non-null  int64
#  7   capital_loss            32537 non-null  int64
#  8   hours_per_week          32537 non-null  int64
#  9   salary                  32537 non-null  object
#  10  age_group               32537 non-null  object
#  11  education_summary       32537 non-null  object
#  12  marital_status_summary  32537 non-null  object
#  13  native_status_summary   32537 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# age_group                 0
# education_summary         0
# marital_status_summary    0
# native_status_summary     0
# dtype: int64

# %%
df["workclass"].value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df["occupation"].value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df[df == '?'] = np.nan
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               30701 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    32537 non-null  object
#  5   gender                  32537 non-null  object
#  6   capital_gain            32537 non-null  int64
#  7   capital_loss            32537 non-null  int64
#  8   hours_per_week          32537 non-null  int64
#  9   salary                  32537 non-null  object
#  10  age_group               32537 non-null  object
#  11  education_summary       32537 non-null  object
#  12  marital_status_summary  32537 non-null  object
#  13  native_status_summary   32537 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# age_group                    0
# education_summary            0
# marital_status_summary       0
# native_status_summary        0
# dtype: int64

# %%
df.dropna().isna().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# age_group                 0
# education_summary         0
# marital_status_summary    0
# native_status_summary     0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# age_group                 0
# education_summary         0
# marital_status_summary    0
# native_status_summary     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   gender                  30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  age_group               30694 non-null  object
#  11  education_summary       30694 non-null  object
#  12  marital_status_summary  30694 non-null  object
#  13  native_status_summary   30694 non-null  object
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
sns.boxplot(data=df);

# %%
df.columns[df.dtypes == "int64"]
# Out:
# Index(['age', 'fnlwgt', 'capital_gain', 'capital_loss', 'hours_per_week'], dtype='object')

# %%
fig, ax = plt.subplots(figsize=(21,10), nrows=2, ncols=3)

sns.boxplot(ax=ax[0,0], x=df.age)
sns.boxplot(ax=ax[0,1], x=df.fnlwgt)
sns.boxplot(ax=ax[0,2], x=df.capital_gain)
sns.boxplot(ax=ax[1,0], x=df.capital_loss)
sns.boxplot(ax=ax[1,1], x=df.hours_per_week)
ax[1,2].remove();

# %%
fig, ax = plt.subplots(figsize=(16,30), nrows=5, ncols=2)

sns.boxplot(ax=ax[0,0], x=df.age)
sns.histplot(ax=ax[0,1], x=df.age)
sns.boxplot(ax=ax[1,0], x=df.fnlwgt)
sns.histplot(ax=ax[1,1], x=df.fnlwgt)
sns.boxplot(ax=ax[2,0], x=df.capital_gain)
sns.histplot(ax=ax[2,1], x=df.capital_gain)
sns.boxplot(ax=ax[3,0], x=df.capital_loss)
sns.histplot(ax=ax[3,1], x=df.capital_loss)
sns.boxplot(ax=ax[4,0], x=df.hours_per_week)
sns.histplot(ax=ax[4,1], x=df.hours_per_week);

# %%
df.loc[:,df.columns[df.dtypes == "int64"]]
# Out:
#        age  fnlwgt  capital_gain  capital_loss  hours_per_week
# 0       39   77516          2174             0              40
# 1       50   83311             0             0              13
# 2       38  215646             0             0              40
# 3       53  234721             0             0              40
# 4       28  338409             0             0              40
# ...    ...     ...           ...           ...             ...
# 32556   27  257302             0             0              38
# 32557   40  154374             0             0              40
# 32558   58  151910             0             0              40
# 32559   22  201490             0             0              20
# 32560   52  287927         15024             0              40
#
# [30694 rows x 5 columns]

# %%
df.loc[:,df.columns[df.dtypes == "int64"]].describe()
# Out:
#             age      fnlwgt  capital_gain  capital_loss  hours_per_week
# count 30694.000   30694.000     30694.000     30694.000       30694.000
# mean     38.448  189848.229      1106.902        88.980          40.953
# std      13.115  105465.126      7500.730       405.808          11.984
# min      17.000   13769.000         0.000         0.000           1.000
# 25%      28.000  117828.500         0.000         0.000          40.000
# 50%      37.000  178513.500         0.000         0.000          40.000
# 75%      47.000  237293.750         0.000         0.000          45.000
# max      90.000 1484705.000     99999.000      4356.000          99.000

# %% [markdown]
# ## Age

# %%
fig, ax = plt.subplots(figsize=(15,6), nrows=1, ncols=2)

sns.boxplot(ax=ax[0], y=df.age)
sns.histplot(ax=ax[1], x=df.age);

# %%
q1_age = df.age.quantile(0.25)
q3_age = df.age.quantile(0.75)
IQR_age = q3_age-q1_age

# %%
lower_age = q1_age - 1.5 * IQR_age
upper_age = q3_age + 1.5 * IQR_age
lower_age, upper_age
# Out:
# (-0.5, 75.5)

# %%
df[df.age > upper_age].age.value_counts()
# Out:
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
df[df.age > upper_age].sort_values(by="age", ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 8806    90           Private   87372   Prof-specialty               White
# 14159   90         Local-gov  187749     Adm-clerical  Asian-Pac-Islander
# 28463   90       Federal-gov  195433     Craft-repair               White
# 12975   90           Private  250832  Exec-managerial               White
# 11996   90           Private   40388  Exec-managerial               White
# ...    ...               ...     ...              ...                 ...
# 15102   76         Local-gov  169133     Adm-clerical               White
# 19085   76           Private  125784  Exec-managerial               White
# 23515   76           Private  142535     Adm-clerical               White
# 8240    76  Self-emp-not-inc  225964            Sales               White
# 23354   76           Private  199949     Adm-clerical               White
#
#        gender  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %% [markdown]
# ## Hours_per_week

# %%
fig, ax = plt.subplots(figsize=(15,6), nrows=1, ncols=2)

sns.boxplot(ax=ax[0], y=df.hours_per_week)
sns.histplot(ax=ax[1], x=df.hours_per_week);

# %%
q1_hourspw = df.hours_per_week.quantile(0.25)
q3_hourspw = df.hours_per_week.quantile(0.75)
IQR_hourspw = q3_hourspw-q1_hourspw

# %%
IQR_hourspw
# Out:
# 5.0

# %%
lower_lim_hpw = q1_hourspw- 1.5 * IQR_hourspw
upper_lim_hpw = q3_hourspw + 1.5 * IQR_hourspw
lower_lim_hpw, upper_lim_hpw
# Out:
# (32.5, 52.5)

# %%
df[df.hours_per_week > upper_lim_hpw].hours_per_week.value_counts().sort_index(ascending=False)
# Out:
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
df[df.hours_per_week > upper_lim_hpw].sort_values(by="hours_per_week", ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation   race  gender  \
# 25986   44         Local-gov  212665   Protective-serv  Black    Male
# 19529   38           Private   66326  Transport-moving  White    Male
# 8796    39           Private   70995  Transport-moving  White    Male
# 15534   29           Private  167716     Other-service  White  Female
# 22313   26  Self-emp-not-inc  258306   Farming-fishing  White    Male
# ...    ...               ...     ...               ...    ...     ...
# 1138    27           Private  138705      Craft-repair  White    Male
# 23244   58           Private  248739   Farming-fishing  White    Male
# 28858   62           Private  123411  Transport-moving  White    Male
# 18417   24           Private  117167     Other-service  White  Female
# 31622   61  Self-emp-not-inc  268831             Sales  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary age_group  \
# ...

# %%
df[df.hours_per_week < lower_lim_hpw].hours_per_week.value_counts().sort_index()
# Out:
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
df_hpw_lower = df[df.hours_per_week < lower_lim_hpw]
df_hpw_lower
# Out:
#        age         workclass  fnlwgt         occupation                race  \
# 1       50  Self-emp-not-inc   83311    Exec-managerial               White
# 6       49           Private  160187      Other-service               Black
# 12      23           Private  122272       Adm-clerical               White
# 21      54           Private  302146      Other-service               Black
# 34      22         State-gov  311512      Other-service               Black
# ...    ...               ...     ...                ...                 ...
# 32524   26           Private  191648  Machine-op-inspct               White
# 32544   31           Private  199655      Other-service               Other
# 32545   39         Local-gov  111499       Adm-clerical               White
# 32553   32           Private  116138       Tech-support  Asian-Pac-Islander
# 32559   22           Private  201490       Adm-clerical               White
#
# ...

# %%
df[df.hours_per_week < lower_lim_hpw].groupby("salary")["hours_per_week"].describe()
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  4372.000 21.548 7.343 1.000 16.000 20.000 30.000 32.000
# >50K    322.000 22.028 7.813 1.000 18.000 24.000 30.000 32.000

# %%
df[df.hours_per_week < lower_lim_hpw].groupby("salary")["age"].describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  4372.000 34.052 17.730 17.000 20.000 26.000 45.000 90.000
# >50K    322.000 49.484 13.894 22.000 39.000 48.000 60.000 90.000

# %%
df[df.hours_per_week > upper_lim_hpw].groupby("salary")["hours_per_week"].describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  1972.000 63.848 10.176 53.000 60.000 60.000 67.250 99.000
# >50K   1430.000 62.483  8.900 53.000 56.000 60.000 65.000 99.000

# %%
df[df.hours_per_week > upper_lim_hpw].groupby("salary")["age"].describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  1972.000 38.559 11.512 18.000 30.000 37.000 46.000 90.000
# >50K   1430.000 43.114  9.737 19.000 36.000 42.000 50.000 90.000

# %% [markdown]
# Result : As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, domain knowledge comes to the fore.
#
# Domain Knowledge for this dataset:
#
# In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# In this respect, our sample space ranges for some features are as follows.
# age : 17 to 80
# hours_per_week : 7 to 70
# if somebody's age is more than 60, he/she can't work more than 60 hours in a week

# %% [markdown]
# ## Dropping rows according to the domain knownledge

# %%
df[(df.age > 80) | (df.age < 17)].sort_values(by="age", ascending=False)
# Out:
#        age     workclass  fnlwgt       occupation   race  gender  \
# 222     90       Private   51744    Other-service  Black    Male
# 18832   90       Private  115306  Exec-managerial  White  Female
# 10545   90       Private  175491     Craft-repair  White    Male
# 11512   90       Private   87285    Other-service  White  Female
# 11996   90       Private   40388  Exec-managerial  White    Male
# ...    ...           ...     ...              ...    ...     ...
# 19045   81     State-gov  132204    Other-service  White  Female
# 6748    81       Private  122651            Sales  White    Male
# 2906    81       Private  114670  Priv-house-serv  Black  Female
# 21501   81       Private  177408  Exec-managerial  White    Male
# 19495   81  Self-emp-inc  247232  Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary        age_group  \
# 222               0          2206              40  <=50K  Greater than 70
# ...

# %%
df[(df.age > 80) | (df.age < 17)].sort_values(by="age", ascending=False).shape
# Out:
# (76, 14)

# %%
age_index = df[(df.age > 80) | (df.age < 17)].sort_values(by="age", ascending=False).index
age_index
# Out:
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
df.drop(index=age_index, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30618 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30618 non-null  int64
#  1   workclass               30618 non-null  object
#  2   fnlwgt                  30618 non-null  int64
#  3   occupation              30618 non-null  object
#  4   race                    30618 non-null  object
#  5   gender                  30618 non-null  object
#  6   capital_gain            30618 non-null  int64
#  7   capital_loss            30618 non-null  int64
#  8   hours_per_week          30618 non-null  int64
#  9   salary                  30618 non-null  object
#  10  age_group               30618 non-null  object
#  11  education_summary       30618 non-null  object
#  12  marital_status_summary  30618 non-null  object
#  13  native_status_summary   30618 non-null  object
# ...

# %%
df[(df.hours_per_week > 70) | (df.hours_per_week < 7)].sort_values(by="hours_per_week", ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 22216   45           Private   54260      Craft-repair               White
# 5432    44           Private   83508    Prof-specialty               White
# 19053   27           Private   40295  Transport-moving               White
# 19141   59           Private  106748     Other-service               White
# 19399   39      Self-emp-inc  163057      Craft-repair               White
# ...    ...               ...     ...               ...                 ...
# 20909   77  Self-emp-not-inc   71676      Adm-clerical               White
# 25078   74           Private  260669     Other-service               White
# 19750   23           Private   72887      Craft-repair  Asian-Pac-Islander
# 189     58         State-gov  109567    Prof-specialty               White
# 24284   57  Self-emp-not-inc   56480   Exec-managerial               White
#
#        gender  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %%
df[(df.hours_per_week > 70) | (df.hours_per_week < 7)].sort_values(by="hours_per_week", ascending=False).shape
# Out:
# (621, 14)

# %%
hpw_index = df[(df.hours_per_week > 70) | (df.hours_per_week < 7)].sort_values(by="hours_per_week", ascending=False).index
hpw_index
# Out:
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
df.drop(index=hpw_index, inplace=True)

# %%
df[(df.hours_per_week > 60) & (df.age > 60)]
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 1541    62           Private  162245    Prof-specialty               White
# 2154    75           Private  101887   Priv-house-serv               White
# 2184    63      Self-emp-inc   54052             Sales               White
# 2665    70           Private   94692             Sales               White
# 3101    65      Self-emp-inc   81413   Farming-fishing               White
# 5417    67           Private  197816             Sales               White
# 6826    68           Private  284763  Transport-moving               White
# 8066    61  Self-emp-not-inc  133969             Sales  Asian-Pac-Islander
# 9646    62  Self-emp-not-inc   26911     Other-service               White
# 12624   63      Self-emp-inc  110890    Prof-specialty               White
# 16634   62  Self-emp-not-inc  115176   Farming-fishing               White
# ...

# %%
df[(df.hours_per_week > 60) & (df.age > 60)].shape
# Out:
# (23, 14)

# %%
df = df.drop("age_group",axis=1)

# %%
age_and_hpw_index= df[(df.hours_per_week > 60) & (df.age > 60)].index
age_and_hpw_index
# Out:
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
df.drop(index=age_and_hpw_index, inplace=True)

# %%
df.shape
# Out:
# (29974, 13)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt         occupation   race  gender  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
# 5   37           Private  284582    Exec-managerial  White  Female
# 6   49           Private  160187      Other-service  Black  Female
# 7   52  Self-emp-not-inc  209642    Exec-managerial  White    Male
# 8   31           Private   45781     Prof-specialty  White  Female
# 9   42           Private  159449    Exec-managerial  White    Male
#
#    capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 0          2174             0              40  <=50K    high_level_grade
# 1             0             0              13  <=50K    high_level_grade
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %%
def sal_mapping (x):
    if x == "<=50K":
        return 0
    else:
        return 1
    
df["salary"] = df.salary.map(sal_mapping)

# %%
df["salary"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
df.salary.value_counts()
# Out:
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# ### Convert all features to numeric by using get_dummies function

# %%
df_new = pd.get_dummies(df, drop_first=True)
df_new
# Out:
#        age  fnlwgt  capital_gain  capital_loss  hours_per_week  salary  \
# 0       39   77516          2174             0              40       0
# 1       50   83311             0             0              13       0
# 2       38  215646             0             0              40       0
# 3       53  234721             0             0              40       0
# 4       28  338409             0             0              40       0
# ...    ...     ...           ...           ...             ...     ...
# 29969   27  257302             0             0              38       0
# 29970   40  154374             0             0              40       1
# 29971   58  151910             0             0              40       0
# 29972   22  201490             0             0              20       0
# 29973   52  287927         15024             0              40       1
#
#        workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# ...

# %%
df.shape
# Out:
# (29974, 13)

# %%
df_new.shape
# Out:
# (29974, 34)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
df_new.corr()
# Out:
#                                         age  fnlwgt  capital_gain  \
# age                                   1.000  -0.074         0.082
# fnlwgt                               -0.074   1.000        -0.002
# capital_gain                          0.082  -0.002         1.000
# capital_loss                          0.059  -0.011        -0.032
# hours_per_week                        0.119  -0.019         0.086
# salary                                0.253  -0.010         0.222
# workclass_Local-gov                   0.070  -0.004        -0.010
# workclass_Private                    -0.211   0.045        -0.045
# workclass_Self-emp-inc                0.111  -0.025         0.093
# workclass_Self-emp-not-inc            0.146  -0.037         0.033
# workclass_State-gov                   0.020  -0.012        -0.013
# workclass_Without-pay                 0.016  -0.003        -0.002
# occupation_Armed-Forces              -0.011   0.004        -0.003
# ...

# %%
plt.figure(figsize=(20,15))

sns.heatmap(df_new.corr(), cmap="YlGnBu", annot=True, fmt =".3f", annot_kws={"fontsize" :10});

# %%
df_corr_salary =df_new.corr()[["salary"]].drop("salary", axis=0).sort_values(by="salary", ascending=False)
df_corr_salary
# Out:
#                                       salary
# age                                    0.253
# hours_per_week                         0.247
# capital_gain                           0.222
# gender_Male                            0.216
# occupation_Exec-managerial             0.215
# occupation_Prof-specialty              0.185
# capital_loss                           0.152
# workclass_Self-emp-inc                 0.138
# race_White                             0.086
# native_status_summary_US               0.035
# workclass_Self-emp-not-inc             0.030
# workclass_Local-gov                    0.029
# occupation_Protective-serv             0.026
# occupation_Tech-support                0.023
# occupation_Sales                       0.015
# race_Asian-Pac-Islander                0.012
# workclass_State-gov                    0.011
# occupation_Armed-Forces               -0.006
# fnlwgt                                -0.010
# workclass_Without-pay                 -0.012
# ...

# %%
plt.figure(figsize=(4,15))

sns.heatmap(df_corr_salary, cmap="YlGnBu", annot=True, fmt =".3f", annot_kws={"fontsize" :10});

# %%
plt.figure(figsize=(10,12))

sns.barplot(x=df_corr_salary.salary, y=df_corr_salary.index);

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
